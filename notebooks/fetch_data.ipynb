# %%
import requests
import pysqlite3
import os
from datetime import datetime
from dotenv import load_dotenv

import libsql_experimental as libsql

load_dotenv()
# Out:
# True

# %%
""" Connect to Turso - embedded replicas """

DB_URL = os.getenv("TURSO_DATABASE_URL")
AUTH_TOKEN = os.getenv("TURSO_AUTH_TOKEN")


conn = libsql.connect("../data/primary.db", sync_url=DB_URL, auth_token=AUTH_TOKEN)

conn.sync()
# Out:
# 2024-12-03T05:42:15.450943Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:42:15.732086Z  WARN libsql::replication::remote_client: Frames prefetching failed because of new session token returned by handshake

# %%
""" load env vars and define paths """

ALPHA_VANTAGE_SECRET = os.getenv("ALPHA_VANTAGE_SECRET")
OPENAI_SECRET = os.getenv("OPEN_AI_SECRET")

ABS_BASE_API_PATH = "https://api.data.abs.gov.au/sdmx-json/data"
ALPHA_VANTAGE_BASE_API_PATH = "https://www.alphavantage.co/query"

# DB_PATH = "../data/macro.db"

# You can specify the response in the API URL using the "format" query parameter. E.g: https://api.data.abs.gov.au/data/jv/all?startPeriod=2020&format=jsondata

# XML is returned by default
# Structure specific XML (good for time series): "format=structurespecificdata"
# JSON: "format=jsondata"
# CSV: "format=csv"

# You can also use the "accept" header to specify the response format as a header when you make an API call. E.g: "accept: application/xml"

# XML: application/xml
# Structure specific XML: application/vnd.sdmx.structurespecificdata+xml
# JSON: application/vnd.sdmx.data+json
# CSV: text/csv
# CSV: application/vnd.sdmx.data+csv
# CSV with labels for codelists: application/vnd.sdmx.data+csv;labels=both
# CSV file with labels for codelists: application/vnd.sdmx.data+csv;file=true;labels=bot


ALPHA_VANTAGE_SECRET
# Out:
# 'GM4049I2JTJHM5J6'

# %%
""" Test API keys """

# Test with Real GDP endpoint
def test_api_key_av(key):
    url = "https://www.alphavantage.co/query"
    params = {
        "function": "REAL_GDP",
        "apikey": key
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        print("API key is working!")
        print(response.json())
    else:
        print(f"Error: {response.status_code} - {response.text}")

test_api_key_av(ALPHA_VANTAGE_SECRET)
# Out:
# API key is working!
# {'name': 'Real Gross Domestic Product', 'interval': 'annual', 'unit': 'billions of dollars', 'data': [{'date': '2023-01-01', 'value': '22671.096'}, {'date': '2022-01-01', 'value': '22034.828'}, {'date': '2021-01-01', 'value': '21494.798'}, {'date': '2020-01-01', 'value': '20267.585'}, {'date': '2019-01-01', 'value': '20715.671'}, {'date': '2018-01-01', 'value': '20193.896'}, {'date': '2017-01-01', 'value': '19612.102'}, {'date': '2016-01-01', 'value': '19141.672'}, {'date': '2015-01-01', 'value': '18799.622'}, {'date': '2014-01-01', 'value': '18261.714'}, {'date': '2013-01-01', 'value': '17812.167'}, {'date': '2012-01-01', 'value': '17442.759'}, {'date': '2011-01-01', 'value': '17052.41'}, {'date': '2010-01-01', 'value': '16789.75'}, {'date': '2009-01-01', 'value': '16349.11'}, {'date': '2008-01-01', 'value': '16781.485'}, {'date': '2007-01-01', 'value': '16762.445'}, {'date': '2006-01-01', 'value': '16433.148'}, {'date': '2005-01-01', 'value': '15987.957'}, {'date': '2004-01-01', 'value': '15449.757
# %%
# """ Define data fetchers for AUSTRALIA """

# def fetch_cpi_data():
#     # CPI request params
#     dataflow_identifier = "ABS,CPI,1.0.0"
#     data_key = "all"
#     params = {
#         "startPeriod": "2023-Q1",
#         "endPeriod": "2024-Q1",
#         "detail": "dataonly",
#         "dimensionAtObservation": "TIME_PERIOD"
#     }
    
#     url = f"{ABS_BASE_API_PATH}/{dataflow_identifier}/{data_key}"
    
#     res = requests.get(url, params=params)
    
#     if res.status_code == 200:
#         data = res.json()
#         return data
#     else:
#         print(f"Error: {res.status_code} - {res.text}")
#         return None

# %%
# """ Fetch data for AUSTRALIA """

# cpi_data = fetch_cpi_data()
# if cpi_data:
#     print("Data fetched successfully")
# else:
#     print("Failed to fetch data.")
# Out:
# Error: 403 - {"message":"Missing Authentication Token"}
# Failed to fetch data.

# %%
""" Define data fetchers and savers for US """

def fetch_economic_indicators_data_av(function, params):
    query_params = {**params, "function": function, "apikey": ALPHA_VANTAGE_SECRET} if params else {"function": function, "apikey": ALPHA_VANTAGE_SECRET}
    
    response = requests.get(ALPHA_VANTAGE_BASE_API_PATH, params=query_params)
    
    if response.status_code == 200:
        data = response.json()
        print(f"Response for {function}: {data}")
        return data
    
    else:
        print(f"Error fetching {function}: {response.status_code}")
        return None
    
def fetch_forex_data(function, from_currency, to_currency, **kwargs):
    params = {
        "function": function,
        "from_currency" if function == "CURRENCY_EXCHANGE_RATE" else "from_symbol": from_currency,
        "to_currency" if function == "CURRENCY_EXCHANGE_RATE" else "to_symbol": to_currency,
        "apikey": ALPHA_VANTAGE_SECRET,
        **kwargs
    }
        
    response = requests.get(ALPHA_VANTAGE_BASE_API_PATH, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"Error {response.status_code}: {response.text}")
    
def fetch_commodity_data(function, **kwargs):
    params = {
        "function": function,
        "apikey": ALPHA_VANTAGE_SECRET,
        **kwargs
    }
    
    response = requests.get(ALPHA_VANTAGE_BASE_API_PATH, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"Error {response.status_code}: {response.text}")
    
    
def filter_by_date(data, start_date=None, end_date=None):
    # Convert start_date and end_date to datetime objects
    if start_date:
        start_date = datetime.strptime(start_date, "%Y-%m-%d")
    if end_date:
        end_date = datetime.strptime(end_date, "%Y-%m-%d")

    # Filter the time series data
    if "data" in data:
        filtered_data = []
        for item in data["data"]:
            item_date = datetime.strptime(item["date"], "%Y-%m-%d")
            if (not start_date or item_date >= start_date) and (not end_date or item_date <= end_date):
                filtered_data.append(item)
        data["data"] = filtered_data

    return data
    
def save_economic_indicator_data(category, data, time_series_key="data"):
    # conn = pysqlite3.connect(DB_PATH)
    # cursor = conn.cursor()
    
    conn.execute(f"""
    CREATE TABLE IF NOT EXISTS {category} (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        date TEXT,
        value REAL
    )           
    """)
    
    for item in data[time_series_key]:
        date = item.get("date")
        value = item.get("value")
        conn.execute(f"""
        INSERT INTO {category} (date, value) VALUES (?, ?)                        
        """, (date, value))
        
    conn.commit()
    # conn.close()
    conn.sync() # embedded replicas only
    
def save_forex_to_db(category, data, time_series_key="Time Series FX (Daily)"):
    # conn = pysqlite3.connect(DB_PATH)
    # cursor = conn.cursor()

    # Create table
    conn.execute(f"""
    CREATE TABLE IF NOT EXISTS {category} (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        date TEXT,
        open REAL,
        high REAL,
        low REAL,
        close REAL
    )
    """)

    # Insert data
    if time_series_key in data:
        for date, values in data[time_series_key].items():
            conn.execute(f"""
            INSERT INTO {category} (date, open, high, low, close) 
            VALUES (?, ?, ?, ?, ?)
            """, (date, float(values["1. open"]), float(values["2. high"]), float(values["3. low"]), float(values["4. close"])))

    conn.commit()
    conn.sync()
    
def save_commodity_to_db(category, data, time_series_key="data"):
    # conn = pysqlite3.connect(DB_PATH)
    # cursor = conn.cursor()

    # Create table
    conn.execute(f"""
    CREATE TABLE IF NOT EXISTS {category} (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        date TEXT,
        value REAL
    )
    """)

    # Insert data
    for item in data[time_series_key]:
        conn.execute(f"""
        INSERT INTO {category} (date, value) VALUES (?, ?)
        """, (item["date"], item["value"]))

    conn.commit()
    # conn.close()
    conn.sync()
    
# def update_raw_data(indicators):
#     results = {"success": [], "errors": []}
#     for category, details in indicators.items():
#         try:
#             print(f"Fetching {category}...")
#             data = fetch_economic_indicators_data_av(details["function"], details["params"])
#             save_economic_indicator_data(category, data)
#             results["success"].append(category)
#             print(f"{category} updated successfully.")
#         except Exception as e:
#             results["errors"].append({"category": category, "error": str(e)})
#             print(f"Error fetching {category}: {e}")

#     return results
    
    
def update_all_data(indicators):
    results = {"success": [], "errors": []}

    for category, details in indicators.items():
        try:
            print(f"Fetching {category}...")
            if "from_currency" in details:
                data = fetch_forex_data(**details)
                save_forex_to_db(category, data)
            elif "commodity" in category:
                data = fetch_commodity_data(**details)
                save_commodity_to_db(category, data)
            else:
                data = fetch_economic_indicators_data_av(details["function"], details["params"])
                save_economic_indicator_data(category, data)
            results["success"].append(category)
            print(f"{category} updated successfully.")
        except Exception as e:
            results["errors"].append({"category": category, "error": str(e)})
            print(f"Error fetching {category}: {e}")

    return results

# %%
""" Define main US fetching loop """

indicators = {
    # Economic indicators
    "real_gdp": {"function": "REAL_GDP", "params": {"interval": "quarterly"}},
    "cpi": {"function": "CPI", "params": {"interval": "monthly"}},
    "treasury_yields": {"function": "TREASURY_YIELD", "params": {"interval": "monthly", "maturity": "10year"}},
    "federal_funds_rate": {"function": "FEDERAL_FUNDS_RATE", "params": {"interval": "monthly"}},
    "unemployment_rate": {"function": "UNEMPLOYMENT", "params": {}},
    "inflation_rate": {"function": "INFLATION", "params": {}},
    
    # Forex
    "forex_usd_aud": {"function": "FX_DAILY", "from_currency": "USD", "to_currency": "AUD"},
    "forex_aud_jpy": {"function": "FX_DAILY", "from_currency": "AUD", "to_currency": "JPY"},

    # Commodities
    "commodity_wti": {"function": "WTI", "interval": "monthly"},
    "commodity_brent": {"function": "BRENT", "interval": "monthly"},
    "commodity_copper": {"function": "COPPER", "interval": "monthly"},
    "commodity_aluminum": {"function": "ALUMINUM", "interval": "monthly"}
}

results = update_all_data(indicators)

# Print Results
print("\nSummary:")
print(f"Success: {results['success']}")
if results["errors"]:
z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:54.340527Z  WARN libsql::replication::remote_client: Unusually long handshake. Took 47 ms, average 20 ms
# 2024-12-03T05:40:54.340542Z  WARN libsql::replication::remote_client: Unusually long frames fetch. Took 47 ms, average 21 ms
# 2024-12-03T05:40:54.377992Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:54.436777Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:54.495414Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:54.547393Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:54.602982Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:54.662232Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:54.721726Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:54.781032Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:54.833407Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:54.892810Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:54.949939Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:55.012374Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:55.067688Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:55.159114Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:55.247399Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:55.296013Z  WARN libsql::replication::remote_client: Unusually long handshake. Took 48 ms, average 20 ms
# 2024-12-03T05:40:55.296025Z  WARN libsql::replication::remote_client: Unusually long frames fetch. Took 48 ms, average 21 ms
# 2024-12-03T05:40:55.366287Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:55.455925Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:55.503661Z  WARN libsql::replication::remote_client: Unusually long handshake. Took 47 ms, average 20 ms
# 2024-12-03T05:40:55.503675Z  WARN libsql::replication::remote_client: Unusually long frames fetch. Took 47 ms, average 21 ms
# 2024-12-03T05:40:55.572268Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:55.644096Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:55.739577Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:55.845862Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:55.927389Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:56.009302Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:56.078874Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:56.129380Z  WARN libsql::replication::remote_client: Unusually long handshake. Took 50 ms, average 20 ms
# 2024-12-03T05:40:56.129393Z  WARN libsql::replication::remote_client: Unusually long frames fetch. Took 50 ms, average 21 ms
# 2024-12-03T05:40:56.180536Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:56.261030Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:56.345884Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:56.388438Z  WARN libsql::replication::remote_client: Unusually long handshake. Took 42 ms, average 20 ms
# 2024-12-03T05:40:56.449690Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:56.530981Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:56.610522Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:56.654057Z  WARN libsql::replication::remote_client: Unusually long handshake. Took 43 ms, average 20 ms
# 2024-12-03T05:40:56.654069Z  WARN libsql::replication::remote_client: Unusually long frames fetch. Took 43 ms, average 21 ms
# 2024-12-03T05:40:56.691521Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:56.736926Z  WARN libsql::replication::remote_client: Unusually long handshake. Took 45 ms, average 20 ms
# 2024-12-03T05:40:56.736941Z  WARN libsql::replication::remote_client: Unusually long frames fetch. Took 45 ms, average 21 ms
# 2024-12-03T05:40:56.797792Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:56.858031Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:56.916709Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:56.977664Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.034394Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.092102Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.145581Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.203240Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.262362Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.322141Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.380624Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.438361Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.497411Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.554788Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.623110Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.704005Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.761008Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.819925Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.890829Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:57.980075Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.049395Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.105431Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.162813Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.222810Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.289143Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.347607Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.401171Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.465031Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.523411Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.579326Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.638282Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.721599Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.777132Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.831363Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.900626Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:58.959909Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.042766Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.099915Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.157064Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.215549Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.274558Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.333129Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.390377Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.450082Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.504540Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.578715Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.631024Z  WARN libsql::replication::remote_client: Unusually long frames fetch. Took 52 ms, average 21 ms
# 2024-12-03T05:40:59.668102Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.743500Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.798125Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.869206Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.929835Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:40:59.986976Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.044606Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.099569Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.169393Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.219642Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.277137Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.335979Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.396855Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.454422Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.512218Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.564945Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.624231Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.683045Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.742879Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.800226Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.853840Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.913252Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:00.970653Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:01.030385Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:01.084277Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:01.145402Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:01.205525Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:01.264050Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:01.318125Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:01.377689Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:01.435495Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:01.530552Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:01.586748Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:01.648390Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:01.683921Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-12-03T05:41:01.714646Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# commodity_aluminum updated successfully.
#
# Summary:
# Success: ['real_gdp', 'cpi', 'treasury_yields', 'federal_funds_rate', 'unemployment_rate', 'inflation_rate', 'forex_usd_aud', 'forex_aud_jpy', 'commodity_wti', 'commodity_brent', 'commodity_copper', 'commodity_aluminum']

# %%
""" Define fetcher for news sentiment individually """


def fetch_news_sentiment(tickers=None, topics=None, time_from=None, time_to=None, sort="LATEST", limit=50):
    """
    Fetch market news and sentiment from Alpha Vantage.
    
    :param tickers: Comma-separated string of tickers (e.g., 'AAPL,TSLA')
    :param topics: Comma-separated string of topics (e.g., 'economy_macro,technology')
    :param time_from: Start time in YYYYMMDDTHHMM format (e.g., '20231101T0000')
    :param time_to: End time in YYYYMMDDTHHMM format (optional)
    :param sort: Sorting order (LATEST, EARLIEST, RELEVANCE)
    :param limit: Number of articles to fetch (default is 50)
    :return: JSON response from the API
    """
    base_url = "https://www.alphavantage.co/query"
    params = {
        "function": "NEWS_SENTIMENT",
        "apikey": ALPHA_VANTAGE_SECRET,
        "tickers": tickers,
        "topics": topics,
        "time_from": time_from,
        "time_to": time_to,
        "sort": sort,
        "limit": limit
    }

    response = requests.get(base_url, params={k: v for k, v in params.items() if v})
    if response.status_code == 200:
        data = response.json()
        print(f"Response for NEWS_SENTIMENT: {data}")
        return data
    
    else:
        print(f"Error fetching NEWS_SENTIMENT: {response.status_code}")
        raise Exception(f"Error {response.status_code}: {response.text}")

# %%
def save_news_to_db(data):
    # conn = pysqlite3.connect(DB_PATH)
    # cursor = conn.cursor()
    
    # Create table
    conn.execute(f"""
    CREATE TABLE IF NOT EXISTS news_sentiment (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        published_at TEXT,
        headline TEXT,
        summary TEXT,
        sentiment_score REAL,
        ticker TEXT,
        topic TEXT
    )
    """)

    # Insert data into the table
    for article in data.get("feed", []):
        conn.execute("""
        INSERT INTO news_sentiment (published_at, headline, summary, sentiment_score, ticker, topic)
        VALUES (?, ?, ?, ?, ?, ?)
        """, (
            article["time_published"],
            article["title"],
            article["summary"],
            article.get("overall_sentiment_score", None),
            article.get("tickers", None),
            article.get("topics", None)
        ))

    conn.commit()
    conn.sync()

# %%
# broad
news_data = fetch_news_sentiment(
    topics="economy_macro,economy_fiscal,economy_monetary",
    time_from="20231101T0000",
    sort="LATEST",
    limit=100
)

# # forex
# news_data = fetch_news_sentiment(
#     tickers="FOREX:USD",
#     topics="economy_macro",
#     time_from="20231101T0000",
#     sort="LATEST",
#     limit=50
# )

# # financial markets
# news_data = fetch_news_sentiment(
#     topics="financial_markets",
#     time_from="20231101T0000",
#     sort="LATEST",
#     limit=100
# )

# # company earnings
# news_data = fetch_news_sentiment(
#     topics="earnings",
#     time_from="20231101T0000",
#     sort="LATEST",
#     limit=100
# )

# # energy and transportation
# news_data = fetch_news_sentiment(
#     topics="energy_transportation",
#     time_from="20231101T0000",
#     sort="LATEST",
#     limit=100
# )


# # real estate and construction
# news_data = fetch_news_sentiment(
#     topics="real_estate",
#     time_from="20231101T0000",
#     sort="LATEST",
#     limit=100
# )

# # Technology
# news_data = fetch_news_sentiment(
#     topics="technology",
#     time_from="20231101T0000",
#     sort="LATEST",
#     limit=100
# )


# # Geopolitical
# news_data = fetch_news_sentiment(
#     topics="economy_macro",
#     time_from="20231101T0000",
#     sort="LATEST",
#     limit=100
# )


# # central bank and policy
# news_data = fetch_news_sentiment(
#     topics="economy_monetary",
#     time_from="20231101T0000",
#     sort="LATEST",
#     limit=100
# )

# # global trade and commodities
# news_data = fetch_news_sentiment(
#     topics="economy_fiscal,economy_macro",
#     time_from="20231101T0000",
#     sort="LATEST",
#     limit=100
# )


# # behavioural indicators
# news_data = fetch_news_sentiment(
#     topics="retail_wholesale",
#     time_from="20231101T0000",
#     sort="LATEST",
#     limit=100
# )

# # Climate and env 
# news_data = fetch_news_sentiment(
#     topics="energy_transportation",
#     time_from="20231101T0000",
#     sort="LATEST",
#     limit=100
# )

# # comprehensive multi-topic
# news_data = fetch_news_sentiment(
#     topics="economy_macro,financial_markets,economy_fiscal,economy_monetary,energy_transportation",
#     time_from="20231101T0000",
#     sort="LATEST",
#     limit=100
# )


save_news_to_db(news_data)
# Out:
# Response for NEWS_SENTIMENT: {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# Response for NEWS_SENTIMENT: {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# Response for NEWS_SENTIMENT: {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# Response for NEWS_SENTIMENT: {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# Response for NEWS_SENTIMENT: {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# Response for NEWS_SENTIMENT: {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# Response for NEWS_SENTIMENT: {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# Response for NEWS_SENTIMENT: {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# Response for NEWS_SENTIMENT: {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# Response for NEWS_SENTIMENT: {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# Response for NEWS_SENTIMENT: {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# Response for NEWS_SENTIMENT: {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# Response for NEWS_SENTIMENT: {'Information': 'Thank you for using Alpha Vantage! Our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
